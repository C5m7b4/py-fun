# %% [markdown]
# # 📘 Welcome to the Interview Project
#
# ---
#
# ## 🧑‍💻 Instructions
#
# Welcome! We're excited to see how you think and code. This project is made up of several short, self-contained exercises split across multiple Jupyter notebooks. Each notebook explores a different set of skills ranging from basic Python to more advanced data wrangling and algorithmic challenges.
#
# ---
#
# ## 🗂 Project Structure
#
# There are **4 notebooks** and **2 bonus notebooks** to complete:
#
# 1. `01-basics.ipynb` - python readiness prep
# 2. `02-bootcamp.ipynb` - implement mean, mode, and median
# 3. `03-pandas_fun.ipynb` - explore and improve a pandas DataFrame
# 4. `04-list_comprehensions.ipynb` - one-liners, transformations, and mental gymnastics with list comprehensions
# 5. `xtra_01_mse.ipynb` - Implement a core ML concepts MSE from scratch
# 6. `xtra_02_r_quared.ipynb` - Implement a core ML concept R² from scratch
# 7. `xtra_03_pearson_correlation.ipynb` - Implement a core ML concept Pearson Correlation from scratch
#
# ---
#
# ## 🔀 What You Need to Do
#
# 1. **Create a new Git branch with your name**:
#
# ```bash
# git checkout -b your-name-here
# ```
#
# 2. Work through the exercises in each notebook. You can start from `01-basics.ipynb` and work your way up.
#
# 3. You are encouraged to:
#    - Use markdown cells to explain your thinking
#    - Write clean and readable code
#    - Handle edge cases when appropriate
#    - Be curious — explore beyond the prompt if you feel inspired 🔥
#    - We are on a time limit so there will only be limited time for each exercise
#    - If you feel like you would be better at another example, feel free to skip exercises
#
# 4. When you're done, push your branch to the repository:
#
# ```bash
# git add .
# git commit -m "Interview exercises completed by <your name>"
# git push origin your-name-here
# ```
#
# ---
#
# ## 🧠 Tips
#
# - Don’t worry if you don’t finish everything — quality > quantity
# - We’re more interested in how you think than whether you remember syntax
# - If you're unsure how to approach something, add a markdown cell and explain your thinking
#
# ---
#
# ## 🚀 Let's Go
#
# Open the first notebook: `01-basics.ipynb` and let the fun begin!
#
# Good luck, and may your imports always be clean and your bugs easily reproducible. 🐛💻
